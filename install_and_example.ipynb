# %% [markdown]
# # Chemical formula to Histogram descriptor (chemhist)
# Nov. 3rd, 2025

# %%
#Install
# !pip install .

# %%
from chemhist import get_descriptor
vec, labels = get_descriptor("Li0.5Mn0.5O2",algebricdesc=True, matrixdesc=True)

# %%
# vec (numpy), labels (list of str))
print (type(labels))
print (labels)
print (len(labels))

print (type(vec))
print (vec)
print (len(vec))
# Out:
# <class 'list'>
# ...
